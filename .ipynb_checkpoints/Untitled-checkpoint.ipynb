# %%
import NS as ns
import pandas as pd
import os
import mysql.connector as SQLconnect
from datetime import datetime as dt

# %%
#transfor weatherdata into database
# Out:
# succes

# %%
#step one: get data out of CSV file
        
files = {dt.strptime(file[26:34], '%Y%m%d') : 'weather_data/' + file for file in os.listdir('weather_data') if '.csv' in file} #bitchin' dict comprehension which gets te csv file out of the directory and links it to a date.

for date in files:
    print(f'{date}: {files[date]}')

raw_weather_data = {date: pd.read_csv(files[date]) for date in files}
# Out:
# 2026-01-25 00:00:00: weather_data/KMDS__OPER_P___10M_OBS_L2_202601252130.nc.csv
# 2026-01-27 00:00:00: weather_data/KMDS__OPER_P___10M_OBS_L2_202601271700.nc.csv
# 2026-01-28 00:00:00: weather_data/KMDS__OPER_P___10M_OBS_L2_202601281130.nc.csv

# %%
#step two: put datatypes into weathertypes database
db = ns.openconnection()

cursor = db.cursor()

val = [
    ('DP',),
    ('DM',), 
    ('DT',), 
    ('MP',), 
    ('MM',), 
    ('MT',),
    ('Null',)
]

sql = 'INSERT INTO weertype VALUES (%s)'

cursor.executemany(sql, val)

cb.close()
# Out:
# Opening connection to database...
# Connection established!
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry 'DP' for key 'weertype.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[133], line 18
#       6 val = [
#       7     ('DP',),
#       8     ('DM',),
#    (...)
#      13     ('Null',)
#      14 ]
#      16 sql = 'INSERT INTO weertype VALUES (%s)'
# ---> 18 cursor.executemany(sql, val)
#      20 cb.close()
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:473, in CMySQLCursor.executemany(self, operation, seq_params)
#     471     if stmt is not None:
#     472         self._executed = stmt
# --> 473         return self.execute(cast(str, stmt))
#     475 rowcnt = 0
#     476 try:
#     477     # When processing read ops (e.g., SELECT), rowcnt is updated
#     478     # based on self._rowcount. For write ops (e.g., INSERT) is
#     479     # updated based on self._affected_rows.
#     480     # The variable self._description is None for write ops, that's
#     481     # why we use it as indicator for updating rowcnt.
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# IntegrityError: 1062 (23000): Duplicate entry 'DP' for key 'weertype.PRIMARY'

# %%
#step three: write function to translate weatherdata into usable type data
    #take into acount missing data in a measurement

def get_classification(file):
    #step 1: open seedfile and extract values for 6 classes
    seed_data = pd.read_csv(file)

    seed_values = {}

    for n in ['DP', 'DM', 'DT', 'MP', 'MM', 'MT']:
        seed_values[n] = {
        'temp': seed_data[f'{n}_temp'].mean() + 10.5,
        'dewp': seed_data[f'{n}_dewp'].mean() + 7
    }

    return(seed_values)


def calculate_dewpoint(temp, hum):
    #Calculate the dewpoint based on magnus formula
    b = 17.625
    c = 243.04
    
    # Calculate gamma
    gamma = np.log(rh / 100.0) + (b * temp) / (c + temp)
    
    # Calculate the dewpoint
    dewpoint = (c * gamma) / (b - gamma)
    return dewpoint



def classify_weather(data, seed):
    #step 2: determine if the data is usable: if not, return 'Null' 
    if data.tg == 'nan' or data.ug == 'nan':
        return None
    else: print(
        data.tg, data.ug
    )
    
    print(data.tg)

# %%
#step four execute function for all available weatherdata and put it into the database

# %%
#step five: write a function that gets weatherdata all weatherstations in a N-km radius around a station

# %%
#step six: get the weather and station data out of the database and put it into a dataframe

# %%
#step seven: use the dataframe to create a table

# %%
#weatherdata test
key = []
for x in raw_weather_data:
    key.append(x)

key = key[1]

test_data = raw_weather_data[key]

seed = get_classification('dutch_seeds.csv')

for row in test_data.itertuples():
    classify_weather(row, seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[218], line 13
#      10 seed = get_classification('dutch_seeds.csv')
#      12 for row in test_data.itertuples():
# ---> 13     classify_weather(row, seed)
#
# Cell In[216], line 35, in classify_weather(data, seed)
#      33 def classify_weather(data, seed):
#      34     #step 2: determine if the data is usable: if not, return 'Null'
# ---> 35     if data.tg == nan or data.ug == nan:
#      36         return None
#      37     else: print(
#      38         data.tg, data.ug
#      39     )
#
# NameError: name 'nan' is not defined
